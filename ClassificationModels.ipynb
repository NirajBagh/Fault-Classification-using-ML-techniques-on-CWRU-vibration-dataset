# %% [markdown]
# <a href="https://colab.research.google.com/github/NirajBagh/Fault-Classification-using-ML-techniques-on-CWRU-vibration-dataset/blob/main/ClassificationModels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load necessary packages and libraries

# %%
import scipy.io
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Import Data

# %%
def ImportData():
  X99_normal = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/99.mat')['X099_DE_time']
  X111_InnerRace_007 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/111.mat')['X111_DE_time']
  X124_Ball_007 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/124.mat')['X124_DE_time']
  X137_Outer_007 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/137.mat')['X137_DE_time']
  X176_InnerRace_014 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/176.mat')['X176_DE_time']
  X191_Ball_014 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/191.mat')['X191_DE_time']
  X203_Outer_014 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/203.mat')['X203_DE_time']
  X215_InnerRace_021 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/215.mat')['X215_DE_time']
  X228_Ball_021 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/228.mat')['X228_DE_time']
  X240_Outer_021 = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/240.mat')['X240_DE_time']
  return [X99_normal,X111_InnerRace_007,X124_Ball_007,X137_Outer_007,X176_InnerRace_014,X191_Ball_014,X203_Outer_014,X215_InnerRace_021,X228_Ball_021,X240_Outer_021]


def Sampling(Data, interval_length, samples_per_block):
  # Calculate the number of blocks that can be sampled based on the interval length
  No_of_blocks = (round(len(Data)/interval_length) - round(samples_per_block/interval_length)-1)
  SplitData = np.zeros([No_of_blocks, samples_per_block])
  for i in range(No_of_blocks):
    SplitData[i,:] = (Data[i*interval_length:(i*interval_length)+samples_per_block]).T
  return SplitData


def DataPreparation(Data, interval_length, samples_per_block):
  for count,i in enumerate(Data):
    SplitData = Sampling(i, interval_length, samples_per_block)
    y = np.zeros([len(SplitData),10])
    y[:,count] = 1
    y1 = np.zeros([len(SplitData),1])
    y1[:,0] = count
    # Stack up and label the data
    if count==0:
      X = SplitData
      LabelPositional = y
      Label = y1
    else:
      X = np.append(X, SplitData, axis=0)
      LabelPositional = np.append(LabelPositional,y,axis=0)
      Label = np.append(Label,y1,axis=0)
  return X, LabelPositional, Label


Data = ImportData()
interval_length = 200
samples_per_block = 1681


# Y_CNN is of shape (n, 10) representing 10 classes as 10 columns. In each sample, for the class to which it belongs,
# the corresponding column value is marked 1 and the rest as 0, facilitating Softmax implementation in CNN
# Y is of shape (m, 1) where column values are between 0 and 9 representing the classes directly. - 1-hot encoding
X, Y_CNN, Y = DataPreparation(Data, interval_length, samples_per_block)


print('Shape of Input Data =', X.shape)
print('Shape of Label Y_CNN =', Y_CNN.shape)
print('Shape of Label Y =', Y.shape)
# Out:
# Shape of Input Data = (24276, 1681)
# Shape of Label Y_CNN = (24276, 10)
# Shape of Label Y = (24276, 1)

# %% [markdown]
# Export Input Data to MATLAB
#
#
# *   For feature Extraction - time and frequency domain analysis
# *   For implementing Self Organizing Feature Maps using MATLAB 'nctool' feature

# %%
XX = {'X':X}
scipy.io.savemat('Data.mat', XX)

# %% [markdown]
# K-Fold Cross Validation

# %%
# k-fold cross validation
kSplits = 5
kfold = KFold(n_splits=kSplits, random_state=32, shuffle=True)

# %% [markdown]
# **NEURAL NETWORK MODELS**

# %% [markdown]
# **1-Dimensional Convolutional Neural Network Classification**

# %%
# Reshape the data - 1 dimensional feed
Input_1D = X.reshape([-1,1681,1])

# Test-Train Split
X_1D_train, X_1D_test, y_1D_train, y_1D_test = train_test_split(Input_1D, Y_CNN, train_size=0.75,test_size=0.25, random_state=101)

# Define the CNN Classification model
class CNN_1D():
    def __init__(self):
        self.model = self.CreateModel()

    def CreateModel(self):
        model = models.Sequential([
            layers.InputLayer(input_shape=(1681, 1)),  # Define input shape here
            layers.Conv1D(filters=16, kernel_size=3, strides=2, activation='relu'),
            layers.MaxPool1D(pool_size=2),
            layers.Conv1D(filters=32, kernel_size=3, strides=2, activation='relu'),
            layers.MaxPool1D(pool_size=2),
            layers.Conv1D(filters=64, kernel_size=3, strides=2, activation='relu'),
            layers.MaxPool1D(pool_size=2),
            layers.Conv1D(filters=128, kernel_size=3, strides=2, activation='relu'),
            layers.MaxPool1D(pool_size=2),
            layers.Flatten(),
            layers.Dense(100, activation='relu'),
            layers.Dense(50, activation='relu'),
            layers.Dense(10),
            layers.Softmax()
        ])
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.CategoricalCrossentropy(),
                      metrics=['accuracy'])
        return model

accuracy_1D = []

# Train the model
for train, test in kfold.split(X_1D_train,y_1D_train):
  Classification_1D = CNN_1D()
  history = Classification_1D.model.fit(X_1D_train[train], y_1D_train[train], verbose=1, epochs=12)

  # Evaluate the accuracy of the model on the training set
  kf_loss, kf_accuracy = Classification_1D.model.evaluate(X_1D_train[test], y_1D_train[test])
  accuracy_1D.append(kf_accuracy)

CNN_1D_train_accuracy = np.average(accuracy_1D)*100
print('CNN 1D train accuracy =', CNN_1D_train_accuracy)


# Evaluate the accuracy of the model on the test set
CNN_1D_test_loss, CNN_1D_test_accuracy = Classification_1D.model.evaluate(X_1D_test, y_1D_test)
CNN_1D_test_accuracy*=100
print('CNN 1D test accuracy =', CNN_1D_test_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.5180 - loss: 1.2365
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8121 - loss: 0.4418
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8878 - loss: 0.2784
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9375 - loss: 0.1598
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9719 - loss: 0.0754
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.0525
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9808 - loss: 0.0620
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9786 - loss: 0.0557
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9867 - loss: 0.0340
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9933 - loss: 0.0210
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9833 - loss: 0.0489
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9932 - loss: 0.0198
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9796 - loss: 0.0634
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5461 - loss: 1.2044
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8312 - loss: 0.3858
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8850 - loss: 0.2433
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9111 - loss: 0.1854
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9263 - loss: 0.1599
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9394 - loss: 0.1431
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9677 - loss: 0.0810
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9809 - loss: 0.0472
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9863 - loss: 0.0372
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0256
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - loss: 0.0171
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9955 - loss: 0.0151
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9917 - loss: 0.0250
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.5180 - loss: 1.2470
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8399 - loss: 0.3690
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8980 - loss: 0.2380
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9181 - loss: 0.1855
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9463 - loss: 0.1276
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9448 - loss: 0.1292
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9665 - loss: 0.0843
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9687 - loss: 0.0868
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9861 - loss: 0.0445
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9822 - loss: 0.0445
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9863 - loss: 0.0361
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9780 - loss: 0.0637
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.5372 - loss: 1.2226
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8431 - loss: 0.3473
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9120 - loss: 0.1900
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9425 - loss: 0.1336
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9767 - loss: 0.0659
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9809 - loss: 0.0566
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9860 - loss: 0.0420
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9842 - loss: 0.0418
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9834 - loss: 0.0428
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9910 - loss: 0.0260
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9885 - loss: 0.0294
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9910 - loss: 0.0252
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9859 - loss: 0.0395
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4814 - loss: 1.3176
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8355 - loss: 0.3553
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8816 - loss: 0.2564
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9109 - loss: 0.1905
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9395 - loss: 0.1361
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9733 - loss: 0.0731
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9777 - loss: 0.0570
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9915 - loss: 0.0280
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9875 - loss: 0.0334
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9855 - loss: 0.0438
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9914 - loss: 0.0247
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9929 - loss: 0.0199
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9855 - loss: 0.0381
# CNN 1D train accuracy = 98.48955988883972
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9844 - loss: 0.0434
# CNN 1D test accuracy = 98.40171337127686

# %% [markdown]
# Confusion Matrix Calculation

# %%
def ConfusionMatrix(Model, X, y):
  y_pred = np.argmax(Model.model.predict(X), axis=1)
  ConfusionMat = confusion_matrix(np.argmax(y, axis=1), y_pred)
  return ConfusionMat

# %% [markdown]
# Plot results - CNN 1D

# %%
plt.figure(1)
plt.title('Confusion Matrix - CNN 1D Train')
sns.heatmap(ConfusionMatrix(Classification_1D, X_1D_train, y_1D_train) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(2)
plt.title('Confusion Matrix - CNN 1D Test')
sns.heatmap(ConfusionMatrix(Classification_1D, X_1D_test, y_1D_test) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(3)
plt.title('Train - Accuracy - CNN 1D')
plt.bar(np.arange(1,kSplits+1),[i*100 for i in accuracy_1D])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.ylim([70,100])
plt.show()

plt.figure(4)
plt.title('Train vs Test Accuracy - CNN 1D')
plt.bar([1,2],[CNN_1D_train_accuracy,CNN_1D_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2],['Train', 'Test'])
plt.ylim([70,100])
plt.show()
# Out:
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# **2-Dimensional Convolutional Neural Network Classification**

# %%
# Reshape the data - 2 dimensional feed
Input_2D = X.reshape([-1,41,41,1])

# Test-Train Split
X_2D_train, X_2D_test, y_2D_train, y_2D_test = train_test_split(Input_2D, Y_CNN, train_size=0.75,test_size=0.25, random_state=101)

# Define the CNN Classification model
class CNN_2D():
  def __init__(self):
    self.model = self.CreateModel()

  def CreateModel(self):
    model = models.Sequential([
        layers.Conv2D(filters=16, kernel_size=(3,3), strides=(2,2), padding ='same',activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Conv2D(filters=32, kernel_size=(3,3),strides=(2,2), padding ='same',activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Conv2D(filters=64, kernel_size=(3,3),strides=(2,2),padding ='same', activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Conv2D(filters=128, kernel_size=(3,3),strides=(2,2),padding ='same', activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Flatten(),
        layers.Dense(100,activation='relu'),
        layers.Dense(50,activation='relu'),
        layers.Dense(10),
        layers.Softmax()
        ])
    model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
    return model


accuracy_2D = []

# Train the model
for train, test in kfold.split(X_2D_train,y_2D_train):
  Classification_2D = CNN_2D()
  history = Classification_2D.model.fit(X_2D_train[train], y_2D_train[train], verbose=1, epochs=12)

  # Evaluate the accuracy of the model on the training set
  kf_loss, kf_accuracy = Classification_2D.model.evaluate(X_2D_train[test], y_2D_train[test])
  accuracy_2D.append(kf_accuracy)

CNN_2D_train_accuracy = np.average(accuracy_2D)*100
print('CNN 2D train accuracy =', CNN_2D_train_accuracy)


# Evaluate the accuracy of the model on the test set
CNN_2D_test_loss, CNN_2D_test_accuracy = Classification_2D.model.evaluate(X_2D_test, y_2D_test)
CNN_2D_test_accuracy*=100
print('CNN 2D test accuracy =', CNN_2D_test_accuracy)
# Out:
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4282 - loss: 1.4665
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8332 - loss: 0.4060
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8593 - loss: 0.3195
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8947 - loss: 0.2545
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9014 - loss: 0.2304
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.1916
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9362 - loss: 0.1564
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9516 - loss: 0.1217
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9529 - loss: 0.1197
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9684 - loss: 0.0838
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9669 - loss: 0.0902
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9756 - loss: 0.0707
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9614 - loss: 0.1363
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.4328 - loss: 1.4368
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7846 - loss: 0.5185
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8304 - loss: 0.4065
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8761 - loss: 0.2989
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8945 - loss: 0.2461
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9145 - loss: 0.2046
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9248 - loss: 0.1763
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9323 - loss: 0.1637
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.1430
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9527 - loss: 0.1165
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9626 - loss: 0.0958
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9673 - loss: 0.0901
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9612 - loss: 0.1065
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.4188 - loss: 1.4712
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8092 - loss: 0.4424
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8563 - loss: 0.3044
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8861 - loss: 0.2429
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9145 - loss: 0.2015
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9490 - loss: 0.1389
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9607 - loss: 0.1020
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9664 - loss: 0.0910
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9754 - loss: 0.0677
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9772 - loss: 0.0641
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9704 - loss: 0.0815
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9821 - loss: 0.0519
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9486 - loss: 0.1453
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4639 - loss: 1.3766
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8439 - loss: 0.3860
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8692 - loss: 0.3204
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8762 - loss: 0.2955
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8916 - loss: 0.2603
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9086 - loss: 0.2278
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9279 - loss: 0.1795
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9350 - loss: 0.1662
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9561 - loss: 0.1195
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9703 - loss: 0.0796
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9740 - loss: 0.0749
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9651 - loss: 0.0968
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9625 - loss: 0.1051
# Epoch 1/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.4883 - loss: 1.3531
# Epoch 2/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8404 - loss: 0.3860
# Epoch 3/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8639 - loss: 0.3229
# Epoch 4/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8800 - loss: 0.2731
# Epoch 5/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9015 - loss: 0.2325
# Epoch 6/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9050 - loss: 0.2324
# Epoch 7/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9109 - loss: 0.2203
# Epoch 8/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9284 - loss: 0.1786
# Epoch 9/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9506 - loss: 0.1265
# Epoch 10/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9630 - loss: 0.0972
# Epoch 11/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9719 - loss: 0.0752
# Epoch 12/12
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9752 - loss: 0.0715
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9650 - loss: 0.0933
# CNN 2D train accuracy = 95.98501801490784
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.0937
# CNN 2D test accuracy = 96.70456647872925

# %% [markdown]
# Plot results - CNN 2D

# %%
plt.figure(5)
plt.title('Confusion Matrix - CNN 2D Train')
sns.heatmap(ConfusionMatrix(Classification_2D, X_2D_train, y_2D_train) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(6)
plt.title('Confusion Matrix - CNN 2D Test')
sns.heatmap(ConfusionMatrix(Classification_2D, X_2D_test, y_2D_test) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(7)
plt.title('Train - Accuracy - CNN 2D')
plt.bar(np.arange(1,kSplits+1),[i*100 for i in accuracy_2D])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.ylim([70,100])
plt.show()

plt.figure(8)
plt.title('Train vs Test Accuracy - CNN 2D')
plt.bar([1,2],[CNN_2D_train_accuracy,CNN_2D_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2],['Train', 'Test'])
plt.ylim([70,100])
plt.show()
# Out:
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# **Long Short-Term Memory Recurrent Neural Network Classification Model**

# %%
# Reshape the data - 1 dimensional feed
Input = X.reshape([-1,1681,1])

# Test-Train Split
X_train, X_test, y_train, y_test = train_test_split(Input, Y_CNN, train_size=0.75,test_size=0.25, random_state=101)

# Define the LSTM Classification model
class LSTM_Model():
  def __init__(self):
    self.model = self.CreateModel()

  def CreateModel(self):
    model = models.Sequential([
        layers.LSTM(32, return_sequences=True),
        layers.Flatten(),
        layers.Dense(10),
        layers.Softmax()
        ])
    model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
    return model


accuracy = []

# Train the model
# Train the model
for train, test in kfold.split(X_train, y_train):
    Classification = LSTM_Model()
    # Remove 'use_multiprocessing=True' here
    history = Classification.model.fit(X_train[train], y_train[train], verbose=1, epochs=10)

    # Evaluate the accuracy of the model on the training set
    kf_loss, kf_accuracy = Classification.model.evaluate(X_train[test], y_train[test])
    accuracy.append(kf_accuracy)

LSTM_train_accuracy = np.average(accuracy)*100
print('LSTM train accuracy =', LSTM_train_accuracy)


# Evaluate the accuracy of the model on the test set
LSTM_test_loss, LSTM_test_accuracy = Classification.model.evaluate(X_test, y_test)
LSTM_test_accuracy*=100
print('LSTM test accuracy =', LSTM_test_accuracy)
# Out:
# Epoch 1/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.4124 - loss: 1.6028
# Epoch 2/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 39s 43ms/step - accuracy: 0.8282 - loss: 0.4573
# Epoch 3/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.8994 - loss: 0.2845
# Epoch 4/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9263 - loss: 0.2059
# Epoch 5/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9417 - loss: 0.1714
# Epoch 6/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.9490 - loss: 0.1341
# Epoch 7/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9514 - loss: 0.1509
# Epoch 8/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.9758 - loss: 0.0802
# Epoch 9/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.9651 - loss: 0.1071
# Epoch 10/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.9805 - loss: 0.0570
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9536 - loss: 0.1803
# Epoch 1/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - accuracy: 0.4187 - loss: 1.6087
# Epoch 2/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.8613 - loss: 0.3969
# Epoch 3/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9056 - loss: 0.2732
# Epoch 4/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9292 - loss: 0.2042
# Epoch 5/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.9452 - loss: 0.1560
# Epoch 6/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9397 - loss: 0.1675
# Epoch 7/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9538 - loss: 0.1978
# Epoch 8/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9750 - loss: 0.0742
# Epoch 9/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.9715 - loss: 0.0935
# Epoch 10/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9702 - loss: 0.1015
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9585 - loss: 0.1854
# Epoch 1/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.4014 - loss: 1.6484
# Epoch 2/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.7922 - loss: 0.5798
# Epoch 3/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.9022 - loss: 0.2868
# Epoch 4/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.9311 - loss: 0.1933
# Epoch 5/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9395 - loss: 0.1684
# Epoch 6/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9430 - loss: 0.1604
# Epoch 7/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.9520 - loss: 0.1425
# Epoch 8/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9452 - loss: 0.1742
# Epoch 9/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9615 - loss: 0.1240
# Epoch 10/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.9691 - loss: 0.0991
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9715 - loss: 0.1171
# Epoch 1/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - accuracy: 0.4261 - loss: 1.6214
# Epoch 2/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.8418 - loss: 0.4478
# Epoch 3/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9160 - loss: 0.2331
# Epoch 4/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9303 - loss: 0.1986
# Epoch 5/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 40s 45ms/step - accuracy: 0.9405 - loss: 0.1730
# Epoch 6/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.9415 - loss: 0.1657
# Epoch 7/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.9537 - loss: 0.1323
# Epoch 8/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.9572 - loss: 0.1305
# Epoch 9/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.9742 - loss: 0.0714
# Epoch 10/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9656 - loss: 0.1114
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.9634 - loss: 0.1183
# Epoch 1/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - accuracy: 0.4067 - loss: 1.6182
# Epoch 2/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.8708 - loss: 0.3550
# Epoch 3/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9204 - loss: 0.2109
# Epoch 4/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9395 - loss: 0.1726
# Epoch 5/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.9485 - loss: 0.1471
# Epoch 6/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.9562 - loss: 0.1158
# Epoch 7/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.9644 - loss: 0.1124
# Epoch 8/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9656 - loss: 0.0947
# Epoch 9/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.9723 - loss: 0.0885
# Epoch 10/10
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.9709 - loss: 0.0932
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9596 - loss: 0.1730
# LSTM train accuracy = 96.15535140037537
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9512 - loss: 0.2000
# LSTM test accuracy = 94.85911726951599

# %% [markdown]
# Plot results - LSTM Model

# %%
plt.figure(9)
plt.title('Confusion Matrix - LSTM Train')
sns.heatmap(ConfusionMatrix(Classification, X_train, y_train) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(10)
plt.title('Confusion Matrix - LSTM Test')
sns.heatmap(ConfusionMatrix(Classification, X_test, y_test) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(11)
plt.title('Train - Accuracy - LSTM')
plt.bar(np.arange(1,kSplits+1),[i*100 for i in accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.ylim([70,100])
plt.show()

plt.figure(12)
plt.title('Train vs Test Accuracy - LSTM')
plt.bar([1,2],[LSTM_train_accuracy,LSTM_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2],['Train', 'Test'])
plt.ylim([70,100])
plt.show()
# Out:
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step

# %% [markdown]
# **SUPPORT VECTOR MACHINE MODEL**

# %% [markdown]
# Import Feature Data
#
#
# *   The input data has been pre processed in MATLAB to extract the features like max, min, peak-to-peak, mean, variance, standard deviation, root-mean-square, skewness, crest factor, kurtosis in time domain, and amplitude and value of the maximum frequency in the frequency domains.

# %%
X_Features = scipy.io.loadmat('/content/drive/MyDrive/Mafaulda dataset/mafaulda/Dataset/X_Features.mat')['Feature_Data']

# Feature data shape (no. of samples, no. of features)
X_Features.shape
# Out:
# (24276, 12)

# %% [markdown]
# Import packages and dependencies

# %%
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Normalize the Input Data

# %%
X_Norm = StandardScaler().fit_transform(X_Features)

# %% [markdown]
# Dimensionality Reduction - Principal Component Analysis

# %%
pca = PCA(n_components=5)
Input_SVM_np = pca.fit_transform(X_Norm)
Input_SVM = pd.DataFrame(data = Input_SVM_np)
Label_SVM = pd.DataFrame(Y, columns = ['target'])

# %% [markdown]
# Define Parameters

# %%
parameters = {'kernel':('rbf','poly','sigmoid'),
              'C': [0.01, 1],
              'gamma' : [0.01, 1],
              'decision_function_shape' : ['ovo']}

# Support vector Machine
svm = SVC()

# %% [markdown]
# Train the Model

# %%
# Test-Train Split
X_train_SVM, X_test_SVM, y_train_SVM, y_test_SVM = train_test_split(Input_SVM_np, Y, train_size=0.75,test_size=0.25, random_state=101)

# Train the model to obtain the best parameters
svm_cv = GridSearchCV(svm, parameters, cv=5)
svm_cv.fit(X_train_SVM, y_train_SVM)

print("Best parameters = ",svm_cv.best_params_)

SVM_train_accuracy = svm_cv.best_score_*100
print('SVM train accuracy =', SVM_train_accuracy)

# Evaluate the accuracy of the model on the test set
SVM_test_accuracy = svm_cv.score(X_test_SVM, y_test_SVM)
SVM_test_accuracy*=100
print('SVM test accuracy =', SVM_test_accuracy)
# Out:
# Best parameters =  {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf'}
# SVM train accuracy = 92.81046553069329
# SVM test accuracy = 92.55231504366452

# %% [markdown]
# Plot results - SVM

# %%
def ConfusionMatrix_SVM(Model, X, y):
  y_pred = Model.predict(X)
  ConfusionMat = confusion_matrix(y, y_pred)
  return ConfusionMat

print(svm_cv.score(X_train_SVM, y_train_SVM))

plt.figure(13)
plt.title('Confusion Matrix - SVM Train')
sns.heatmap(ConfusionMatrix_SVM(svm_cv, X_train_SVM, y_train_SVM) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(14)
plt.title('Confusion Matrix - SVM Test')
sns.heatmap(ConfusionMatrix_SVM(svm_cv, X_test_SVM, y_test_SVM) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(16)
plt.title('Train vs Test Accuracy - SVM')
plt.bar([1,2],[SVM_train_accuracy,SVM_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2],['Train', 'Test'])
plt.ylim([70,100])
plt.show()
# Out:
# 0.9367276322293623

# %% [markdown]
# Plot Decision boundaries in 2D

# %%
from mlxtend.plotting import plot_decision_regions
value = 0
width = 1
plt.figure(17)
plt.figure(figsize=(10.4,8.8))
plt.title('Decision Boundary - SVM')
plot_decision_regions(X_test_SVM, (y_test_SVM.astype(np.integer)).flatten(), clf=svm_cv, legend=2,
                  feature_index=[0,1],
                  filler_feature_values={2:value, 3:value, 4:value},
                  filler_feature_ranges={2:width, 3:width, 4:width},)
plt.show()

# %% [markdown]
# **COMPARISON OF MODELS**

# %%
plt.figure(18)
plt.title('Accuracy in Training data')
plt.bar([1,2,3,4],[CNN_1D_train_accuracy, CNN_2D_train_accuracy, LSTM_train_accuracy, SVM_train_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2,3,4],['CNN-1D', 'CNN-2D' , 'LSTM', 'SVM'])
plt.ylim([70,100])
plt.show()


plt.figure(19)
plt.title('Accuracy in Test data')
plt.bar([1,2,3,4],[CNN_1D_test_accuracy, CNN_2D_test_accuracy, LSTM_test_accuracy, SVM_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2,3,4],['CNN-1D', 'CNN-2D' , 'LSTM', 'SVM'])
plt.ylim([70,100])
plt.show()
